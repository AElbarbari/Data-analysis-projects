# %%
### importing libery

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline 
sns.set()

# %% [markdown]
# ### importing data

# %%
df = pd.read_csv('https://covid.ourworldindata.org/data/owid-covid-data.csv')

# %%
df
# Out:
#        iso_code continent     location        date  total_cases  new_cases  \
# 0           AFG      Asia  Afghanistan  2020-01-03          NaN        0.0
# 1           AFG      Asia  Afghanistan  2020-01-04          NaN        0.0
# 2           AFG      Asia  Afghanistan  2020-01-05          NaN        0.0
# 3           AFG      Asia  Afghanistan  2020-01-06          NaN        0.0
# 4           AFG      Asia  Afghanistan  2020-01-07          NaN        0.0
# ...         ...       ...          ...         ...          ...        ...
# 344906      ZWE    Africa     Zimbabwe  2023-09-23     265748.0        0.0
# 344907      ZWE    Africa     Zimbabwe  2023-09-24     265748.0        0.0
# 344908      ZWE    Africa     Zimbabwe  2023-09-25     265748.0        0.0
# 344909      ZWE    Africa     Zimbabwe  2023-09-26     265748.0        0.0
# 344910      ZWE    Africa     Zimbabwe  2023-09-27     265748.0        0.0
#
# ...

# %%
df.head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-01-03          NaN        0.0
# 1      AFG      Asia  Afghanistan  2020-01-04          NaN        0.0
# 2      AFG      Asia  Afghanistan  2020-01-05          NaN        0.0
# 3      AFG      Asia  Afghanistan  2020-01-06          NaN        0.0
# 4      AFG      Asia  Afghanistan  2020-01-07          NaN        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         0.0                  NaN  ...
# 1                 NaN           NaN         0.0                  NaN  ...
# 2                 NaN           NaN         0.0                  NaN  ...
# 3                 NaN           NaN         0.0                  NaN  ...
# 4                 NaN           NaN         0.0                  NaN  ...
#
#    male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# ...

# %%
df.tail()
# Out:
#        iso_code continent  location        date  total_cases  new_cases  \
# 344906      ZWE    Africa  Zimbabwe  2023-09-23     265748.0        0.0
# 344907      ZWE    Africa  Zimbabwe  2023-09-24     265748.0        0.0
# 344908      ZWE    Africa  Zimbabwe  2023-09-25     265748.0        0.0
# 344909      ZWE    Africa  Zimbabwe  2023-09-26     265748.0        0.0
# 344910      ZWE    Africa  Zimbabwe  2023-09-27     265748.0        0.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 344906                 0.0        5718.0         0.0                  0.0
# 344907                 0.0        5718.0         0.0                  0.0
# 344908                 0.0        5718.0         0.0                  0.0
# 344909                 0.0        5718.0         0.0                  0.0
# 344910                 0.0        5718.0         0.0                  0.0
#
#         ...  male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# ...

# %%
df.sample(15)
# Out:
#        iso_code      continent  location        date  total_cases  new_cases  \
# 343428      ZMB         Africa    Zambia  2023-06-01     343995.0        0.0
# 50477       KHM           Asia  Cambodia  2023-09-11     138940.0        0.0
# 144474      IRL         Europe   Ireland  2023-08-16    1716301.0       11.0
# 241378      PER  South America      Peru  2023-07-07    4512091.0        0.0
# 142900      IRQ           Asia      Iraq  2023-01-18    2465545.0        0.0
# 73942       CYP         Europe    Cyprus  2020-09-15       1534.0        8.0
# 312974      TUN         Africa   Tunisia  2021-10-16     710673.0      131.0
# 183783      MLI         Africa      Mali  2020-09-09       2882.0       12.0
# 101151      FJI        Oceania      Fiji  2020-09-03         29.0        0.0
# 112534      DEU         Europe   Germany  2021-12-18    6546708.0        0.0
# 306746      TLS           Asia     Timor  2023-05-31      23450.0        0.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344911 entries, 0 to 344910
# Data columns (total 67 columns):
#  #   Column                                      Non-Null Count   Dtype
# ---  ------                                      --------------   -----
#  0   iso_code                                    344911 non-null  object
#  1   continent                                   328489 non-null  object
#  2   location                                    344911 non-null  object
#  3   date                                        344911 non-null  object
#  4   total_cases                                 306964 non-null  float64
#  5   new_cases                                   335338 non-null  float64
#  6   new_cases_smoothed                          334079 non-null  float64
#  7   total_deaths                                285503 non-null  float64
#  8   new_deaths                                  335378 non-null  float64
# ...

# %%
df.shape
# Out:
# (344911, 67)

# %%
df.describe()
# Out:
#         total_cases     new_cases  new_cases_smoothed  total_deaths  \
# count  3.069640e+05  3.353380e+05        3.340790e+05  2.855030e+05
# mean   6.571274e+06  9.740990e+03        9.777569e+03  8.538039e+04
# std    4.013913e+07  1.111088e+05        9.519139e+04  4.371278e+05
# min    1.000000e+00  0.000000e+00        0.000000e+00  1.000000e+00
# 25%    7.910000e+03  0.000000e+00        2.860000e-01  1.250000e+02
# 50%    6.889000e+04  2.000000e+00        2.600000e+01  1.302000e+03
# 75%    7.269022e+05  2.760000e+02        5.151430e+02  1.174400e+04
# max    7.708747e+08  8.401961e+06        6.402036e+06  6.959303e+06
#
#           new_deaths  new_deaths_smoothed  total_cases_per_million  \
# count  335378.000000        334148.000000            306964.000000
# mean       86.777994            87.093917            100066.612321
# std       618.277391           563.307165            149790.634356
# min         0.000000             0.000000                 0.000000
# ...

# %%
df.describe().T
# Out:
#                                             count          mean           std  \
# total_cases                              306964.0  6.571274e+06  4.013913e+07
# new_cases                                335338.0  9.740990e+03  1.111088e+05
# new_cases_smoothed                       334079.0  9.777569e+03  9.519139e+04
# total_deaths                             285503.0  8.538039e+04  4.371278e+05
# new_deaths                               335378.0  8.677799e+01  6.182774e+02
# ...                                           ...           ...           ...
# population                               344911.0  1.284927e+08  6.608878e+08
# excess_mortality_cumulative_absolute      11944.0  5.113397e+04  1.443228e+05
# excess_mortality_cumulative               11944.0  9.738000e+00  1.238457e+01
# excess_mortality                          11944.0  1.146195e+01  2.536237e+01
# excess_mortality_cumulative_per_million   11944.0  1.644920e+03  1.927691e+03
#
# ...

# %%
df.head(5).style.background_gradient(cmap='Blues')
# Out:
# c:\Users\Elbarbari\anaconda3\Lib\site-packages\pandas\io\formats\style.py:3931: RuntimeWarning: All-NaN slice encountered
#   smin = np.nanmin(gmap) if vmin is None else vmin
# c:\Users\Elbarbari\anaconda3\Lib\site-packages\pandas\io\formats\style.py:3932: RuntimeWarning: All-NaN slice encountered
#   smax = np.nanmax(gmap) if vmax is None else vmax
# <style type="text/css">
# ...

# %%
df['location']
# Out:
# 0         Afghanistan
# 1         Afghanistan
# 2         Afghanistan
# 3         Afghanistan
# 4         Afghanistan
#              ...
# 344906       Zimbabwe
# 344907       Zimbabwe
# 344908       Zimbabwe
# 344909       Zimbabwe
# 344910       Zimbabwe
# Name: location, Length: 344911, dtype: object

# %%
df['location'].unique()
# Out:
# array(['Afghanistan', 'Africa', 'Albania', 'Algeria', 'American Samoa',
#        'Andorra', 'Angola', 'Anguilla', 'Antigua and Barbuda',
#        'Argentina', 'Armenia', 'Aruba', 'Asia', 'Australia', 'Austria',
#        'Azerbaijan', 'Bahamas', 'Bahrain', 'Bangladesh', 'Barbados',
#        'Belarus', 'Belgium', 'Belize', 'Benin', 'Bermuda', 'Bhutan',
#        'Bolivia', 'Bonaire Sint Eustatius and Saba',
#        'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'British Virgin Islands', 'Brunei', 'Bulgaria', 'Burkina Faso',
#        'Burundi', 'Cambodia', 'Cameroon', 'Canada', 'Cape Verde',
#        'Cayman Islands', 'Central African Republic', 'Chad', 'Chile',
#        'China', 'Colombia', 'Comoros', 'Congo', 'Cook Islands',
#        'Costa Rica', "Cote d'Ivoire", 'Croatia', 'Cuba', 'Curacao',
#        'Cyprus', 'Czechia', 'Democratic Republic of Congo', 'Denmark',
#        'Djibouti', 'Dominica', 'Dominican Republic', 'Ecuador', 'Egypt',
# ...

# %%
df['location'].nunique()
# Out:
# 255

# %% [markdown]
# ## Using germany data

# %%
df_Germany =df[df["location"]=='Germany']

df_Germany.reset_index(drop= True, inplace = True)


df_Germany
# Out:
#      iso_code continent location        date  total_cases  new_cases  \
# 0         DEU    Europe  Germany  2020-01-03          NaN        0.0
# 1         DEU    Europe  Germany  2020-01-04          1.0        1.0
# 2         DEU    Europe  Germany  2020-01-05          1.0        0.0
# 3         DEU    Europe  Germany  2020-01-06          1.0        0.0
# 4         DEU    Europe  Germany  2020-01-07          1.0        0.0
# ...       ...       ...      ...         ...          ...        ...
# 1359      DEU    Europe  Germany  2023-09-23   38437756.0        0.0
# 1360      DEU    Europe  Germany  2023-09-24   38437756.0        0.0
# 1361      DEU    Europe  Germany  2023-09-25   38437756.0        0.0
# 1362      DEU    Europe  Germany  2023-09-26   38437756.0        0.0
# 1363      DEU    Europe  Germany  2023-09-27   38437756.0        0.0
#
#       new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# ...

# %% [markdown]
# ### Finding max deaths in pation with cardioVisc

# %%
df_Germany['new_deaths_per_million'].max()
# Out:
# 77.486

# %%
df_Germany[df_Germany['new_deaths_per_million']==df_Germany['new_deaths_per_million'].max()]
# Out:
#     iso_code continent location        date  total_cases  new_cases  \
# 352      DEU    Europe  Germany  2020-12-20    1521350.0   174589.0
#
#      new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 352           24941.286       41281.0      6460.0              922.857  ...
#
#      male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# 352          33.1                     NaN                         8.0
#
#      life_expectancy  human_development_index  population  \
# 352            81.33                    0.947  83369840.0
#
#      excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 352                               17710.5                          1.9
#
#      excess_mortality  excess_mortality_cumulative_per_million
# 352             29.54                                212.53708
#
# [1 rows x 67 columns]

# %%
df_Germany['excess_mortality_cumulative_absolute'].max()
# Out:
# 205167.25

# %%
df_Germany[df_Germany['excess_mortality_cumulative_absolute'] == df_Germany['excess_mortality_cumulative_absolute'].max()]
# Out:
#      iso_code continent location        date  total_cases  new_cases  \
# 1269      DEU    Europe  Germany  2023-06-25   38436657.0     1528.0
#
#       new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 1269             218.286      174971.0        15.0                2.143  ...
#
#       male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# 1269          33.1                     NaN                         8.0
#
#       life_expectancy  human_development_index  population  \
# 1269            81.33                    0.947  83369840.0
#
#       excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 1269                             205167.25                         6.06
#
#       excess_mortality  excess_mortality_cumulative_per_million
# 1269              4.13                                 2463.151
#
# [1 rows x 67 columns]

# %% [markdown]
# ### Finding the date of max excess_mortality_cumulative_absolute

# %%
df_Germany[df_Germany ['excess_mortality_cumulative_absolute'] == df_Germany['excess_mortality_cumulative_absolute'].max()]['date']
# Out:
# 1269    2023-06-25
# Name: date, dtype: object

# %%
df_Germany['excess_mortality_cumulative_absolute'].idxmax()
# Out:
# 1269

# %%
df_Germany.loc[df_Germany['excess_mortality_cumulative_absolute'].idxmax()] ['date']
# Out:
# '2023-06-25'

# %%
df_Germany[df_Germany['excess_mortality_cumulative_absolute'] == df_Germany['excess_mortality_cumulative_absolute'].min()]
# Out:
#    iso_code continent location        date  total_cases  new_cases  \
# 79      DEU    Europe  Germany  2020-03-22      29923.0    22407.0
#
#     new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 79              3201.0         586.0       479.0               68.429  ...
#
#     male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# 79          33.1                     NaN                         8.0
#
#     life_expectancy  human_development_index  population  \
# 79            81.33                    0.947  83369840.0
#
#     excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 79                              -17779.2                        -7.11
#
#     excess_mortality  excess_mortality_cumulative_per_million
# 79             -1.74                               -213.36151
#
# [1 rows x 67 columns]

# %%
df_Germany[df_Germany['excess_mortality_cumulative_absolute'] == df_Germany['excess_mortality_cumulative_absolute'].min()]['date']
# Out:
# 79    2020-03-22
# Name: date, dtype: object

# %%
df_Germany['excess_mortality_cumulative_absolute'].idxmin()
# Out:
# 79

# %% [markdown]
# ### 2nd way

# %%
df_Germany['excess_mortality_cumulative_absolute'].argmax()
# Out:
# 1269

# %%
df_Germany.iloc[df_Germany['excess_mortality_cumulative_absolute'].argmax()]
# Out:
# iso_code                                          DEU
# continent                                      Europe
# location                                      Germany
# date                                       2023-06-25
# total_cases                                38436657.0
#                                               ...
# population                                 83369840.0
# excess_mortality_cumulative_absolute        205167.25
# excess_mortality_cumulative                      6.06
# excess_mortality                                 4.13
# excess_mortality_cumulative_per_million      2463.151
# Name: 1269, Length: 67, dtype: object

# %%
df_Germany.iloc[df_Germany['excess_mortality_cumulative_absolute'].argmax()]['date']
# Out:
# '2023-06-25'

# %%
df_Germany.iloc[df_Germany['excess_mortality_cumulative_absolute'].argmin()]['date']
# Out:
# '2020-03-22'

# %% [markdown]
# ### Creating a summary table for the most recent date all over the Germany

# %%
df_Germany
# Out:
#      iso_code continent location        date  total_cases  new_cases  \
# 0         DEU    Europe  Germany  2020-01-03          NaN        0.0
# 1         DEU    Europe  Germany  2020-01-04          1.0        1.0
# 2         DEU    Europe  Germany  2020-01-05          1.0        0.0
# 3         DEU    Europe  Germany  2020-01-06          1.0        0.0
# 4         DEU    Europe  Germany  2020-01-07          1.0        0.0
# ...       ...       ...      ...         ...          ...        ...
# 1359      DEU    Europe  Germany  2023-09-23   38437756.0        0.0
# 1360      DEU    Europe  Germany  2023-09-24   38437756.0        0.0
# 1361      DEU    Europe  Germany  2023-09-25   38437756.0        0.0
# 1362      DEU    Europe  Germany  2023-09-26   38437756.0        0.0
# 1363      DEU    Europe  Germany  2023-09-27   38437756.0        0.0
#
#       new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# ...

# %%
df_Germany['date'].sort_values(ascending = False).head(1)
# Out:
# 1363    2023-09-27
# Name: date, dtype: object

# %%
df_Germany.sort_values(['date'], ascending = False).head(1)
# Out:
#      iso_code continent location        date  total_cases  new_cases  \
# 1363      DEU    Europe  Germany  2023-09-27   38437756.0        0.0
#
#       new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 1363                 0.0      174979.0         0.0                  0.0  ...
#
#       male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# 1363          33.1                     NaN                         8.0
#
#       life_expectancy  human_development_index  population  \
# 1363            81.33                    0.947  83369840.0
#
#       excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 1363                                   NaN                          NaN
#
#       excess_mortality  excess_mortality_cumulative_per_million
# 1363               NaN                                      NaN
#
# [1 rows x 67 columns]

# %% [markdown]
# ### Removing nan value Raw

# %%
df_Germany = df_Germany.iloc[:-2]

# %%
df_Germany.sort_values(['date'], ascending = False).head(20)
# Out:
#      iso_code continent location        date  total_cases  new_cases  \
# 1361      DEU    Europe  Germany  2023-09-25   38437756.0        0.0
# 1360      DEU    Europe  Germany  2023-09-24   38437756.0        0.0
# 1359      DEU    Europe  Germany  2023-09-23   38437756.0        0.0
# 1358      DEU    Europe  Germany  2023-09-22   38437756.0        0.0
# 1357      DEU    Europe  Germany  2023-09-21   38437756.0        0.0
# 1356      DEU    Europe  Germany  2023-09-20   38437756.0        0.0
# 1355      DEU    Europe  Germany  2023-09-19   38437756.0        0.0
# 1354      DEU    Europe  Germany  2023-09-18   38437756.0        0.0
# 1353      DEU    Europe  Germany  2023-09-17   38437756.0        0.0
# 1352      DEU    Europe  Germany  2023-09-16   38437756.0        0.0
# 1351      DEU    Europe  Germany  2023-09-15   38437756.0        0.0
# 1350      DEU    Europe  Germany  2023-09-14   38437756.0        0.0
# 1349      DEU    Europe  Germany  2023-09-13   38437756.0        0.0
# ...

# %%
df_Germany_recent = df_Germany[df_Germany['date']== df_Germany.date.max()]

df_Germany_recent
# Out:
#      iso_code continent location        date  total_cases  new_cases  \
# 1361      DEU    Europe  Germany  2023-09-25   38437756.0        0.0
#
#       new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 1361                 0.0      174979.0         0.0                  0.0  ...
#
#       male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# 1361          33.1                     NaN                         8.0
#
#       life_expectancy  human_development_index  population  \
# 1361            81.33                    0.947  83369840.0
#
#       excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 1361                                   NaN                          NaN
#
#       excess_mortality  excess_mortality_cumulative_per_million
# 1361               NaN                                      NaN
#
# [1 rows x 67 columns]

# %%
df_Germany.bfill()
# Out:
#      iso_code continent location        date  total_cases  new_cases  \
# 0         DEU    Europe  Germany  2020-01-03          1.0        0.0
# 1         DEU    Europe  Germany  2020-01-04          1.0        1.0
# 2         DEU    Europe  Germany  2020-01-05          1.0        0.0
# 3         DEU    Europe  Germany  2020-01-06          1.0        0.0
# 4         DEU    Europe  Germany  2020-01-07          1.0        0.0
# ...       ...       ...      ...         ...          ...        ...
# 1357      DEU    Europe  Germany  2023-09-21   38437756.0        0.0
# 1358      DEU    Europe  Germany  2023-09-22   38437756.0        0.0
# 1359      DEU    Europe  Germany  2023-09-23   38437756.0        0.0
# 1360      DEU    Europe  Germany  2023-09-24   38437756.0        0.0
# 1361      DEU    Europe  Germany  2023-09-25   38437756.0        0.0
#
#       new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# ...

# %%
plt.figure(figsize=(20,20))
plt.plot(df_Germany.index, df_Germany['total_cases'])



 
plt.title('Evolution of Confirmed Covid-19 cases over time in Germany', fontsize=16)
plt.xlabel('Days', fontsize=16)
plt.ylabel('Confirmed cases', fontsize=16)
plt.show()

# %%
df_Germany['date'] = pd.to_datetime(df_Germany['date'])
plt.figure(figsize=(20,20))
plt.plot(df_Germany['date'], df_Germany['total_cases'])

plt.title('Evolution of Confirmed Covid-19 cases over time in Germany', fontsize=16)
plt.xlabel('Days', fontsize=16)
plt.ylabel('Confirmed cases', fontsize=16)
plt.show()
# Out:
# C:\Users\Elbarbari\AppData\Local\Temp\ipykernel_36632\3238492021.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_Germany['date'] = pd.to_datetime(df_Germany['date'])

# %%
df_Germany
# Out:
#      iso_code continent location       date  total_cases  new_cases  \
# 0         DEU    Europe  Germany 2020-01-03          NaN        0.0
# 1         DEU    Europe  Germany 2020-01-04          1.0        1.0
# 2         DEU    Europe  Germany 2020-01-05          1.0        0.0
# 3         DEU    Europe  Germany 2020-01-06          1.0        0.0
# 4         DEU    Europe  Germany 2020-01-07          1.0        0.0
# ...       ...       ...      ...        ...          ...        ...
# 1357      DEU    Europe  Germany 2023-09-21   38437756.0        0.0
# 1358      DEU    Europe  Germany 2023-09-22   38437756.0        0.0
# 1359      DEU    Europe  Germany 2023-09-23   38437756.0        0.0
# 1360      DEU    Europe  Germany 2023-09-24   38437756.0        0.0
# 1361      DEU    Europe  Germany 2023-09-25   38437756.0        0.0
#
#       new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# ...
